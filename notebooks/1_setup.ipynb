# %% [markdown]
# Run the cell only one time for installation

# %%
# !pip install torch torchvision --quiet
# !pip install transformers sentence-transformers --quiet
# !pip install faiss-cpu --quiet
# !pip install gradio --quiet
# !pip install fastapi uvicorn --quiet
# !pip install pillow opencv-python pandas --quiet
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 23.7/23.7 MB 96.2 MB/s eta 0:00:00

# %% [markdown]
# Mount the drive

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# Path to the project

# %%
PROJECT_DIR = '/content/drive/MyDrive/product_search_engine'
DATA_DIR = f"{PROJECT_DIR}/data"

# %%
# !kaggle datasets download -d paramaggarwal/fashion-product-images-small -p "{PROJECT_DIR}/data"
# !unzip -q "{PROJECT_DIR}/data/fashion-product-images-small.zip" -d "{PROJECT_DIR}/data/"
# Out:
# Dataset URL: https://www.kaggle.com/datasets/paramaggarwal/fashion-product-images-small
# License(s): MIT
# ...
#  98% 556M/565M [00:05<00:00, 114MB/s]
# 100% 565M/565M [00:05<00:00, 114MB/s]

# %% [markdown]
# ### Extract the images from the zip file

# %%
import os

print(os.listdir(DATA_DIR))
# Out:
# ['fashion-product-images-small.zip', 'images2', 'myntradataset']

# %% [markdown]
# * Automatically replace all the files while unzipping in case unzip fails without finishing completely

# %%
# !yes | unzip "{DATA_DIR}/fashion-product-images-small.zip" -d "{DATA_DIR}"
# Out:
# Streaming output truncated to the last 5000 lines.
# replace /content/drive/MyDrive/product_search_engine/data/myntradataset/images/54988.jpg? [y]es, [n]o, [A]ll, [N]one, [r]ename:   inflating: /content/drive/MyDrive/product_search_engine/data/myntradataset/images/54988.jpg
# replace /content/drive/MyDrive/product_search_engine/data/myntradataset/images/54989.jpg? [y]es, [n]o, [A]ll, [N]one, [r]ename:   inflating: /content/drive/MyDrive/product_search_engine/data/myntradataset/images/54989.jpg
# replace /content/drive/MyDrive/product_search_engine/data/myntradataset/images/5499.jpg? [y]es, [n]o, [A]ll, [N]one, [r]ename:   inflating: /content/drive/MyDrive/product_search_engine/data/myntradataset/images/5499.jpg
# replace /content/drive/MyDrive/product_search_engine/data/myntradataset/images/54990.jpg? [y]es, [n]o, [A]ll, [N]one, [r]ename:   inflating: /content/drive/MyDrive/product_search_engine/data/myntradataset/images/54990.jpg
# ...

# %% [markdown]
# * Check the number of files present to ensure all files have been extracted

# %%
# !ls "{DATA_DIR}/images" | wc -l
# Out:
# 44441
