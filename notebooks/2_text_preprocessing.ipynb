# %% [markdown]
# Mount the Drive

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# Load the packages

# %%
import pandas as pd
import re

# %%
PROJECT_DIR = '/content/drive/MyDrive/product_search_engine'
DATA_DIR = f"{PROJECT_DIR}/data"

# %% [markdown]
# Load the dataset

# %%
df = pd.read_csv(f"{DATA_DIR}/cleaned_products.csv")
df.head()
# Out:
#       id gender masterCategory subCategory  articleType baseColour  season  \
# 0  15970    Men        Apparel     Topwear       Shirts  Navy Blue    Fall
# 1  39386    Men        Apparel  Bottomwear        Jeans       Blue  Summer
# 2  59263  Women    Accessories     Watches      Watches     Silver  Winter
# 3  21379    Men        Apparel  Bottomwear  Track Pants      Black    Fall
# 4  53759    Men        Apparel     Topwear      Tshirts       Grey  Summer
#
#      year   usage                             productDisplayName  \
# 0  2011.0  Casual               Turtle Check Men Navy Blue Shirt
# 1  2012.0  Casual             Peter England Men Party Blue Jeans
# 2  2016.0  Casual                       Titan Women Silver Watch
# 3  2011.0  Casual  Manchester United Men Solid Black Track Pants
# 4  2012.0  Casual                          Puma Men Grey T-shirt
#
#                                          images_path
# 0  /content/drive/MyDrive/product_search_engine/d...
# ...

# %% [markdown]
# ### Clean the text

# %%
def clean_text(text):
  text = text.lower() # Convert the text into lowercase
  text = re.sub(r"[^a-z0-9\s]", "", text) # Remove punctuations and special sybols
  text = re.sub(r"\s+", " ", text).strip() # Remove extra whitespace

  return text

# %% [markdown]
# Add metadata to the input text

# %%
df['text_input'] = (
    df['productDisplayName'].fillna('') + '. ' +
    "Category : " + df['masterCategory'] + '. ' +
    "Type : " + df['articleType'] + '. ' +
    "Color: " + df['baseColour'].fillna('')
    )

# %%
# Remove the punctuations, special symbols, and whitespaces
df['text_input'] = df['text_input'].apply(clean_text)

# %%
df.head()
# Out:
#       id gender masterCategory subCategory  articleType baseColour  season  \
# 0  15970    Men        Apparel     Topwear       Shirts  Navy Blue    Fall
# 1  39386    Men        Apparel  Bottomwear        Jeans       Blue  Summer
# 2  59263  Women    Accessories     Watches      Watches     Silver  Winter
# 3  21379    Men        Apparel  Bottomwear  Track Pants      Black    Fall
# 4  53759    Men        Apparel     Topwear      Tshirts       Grey  Summer
#
#      year   usage                             productDisplayName  \
# 0  2011.0  Casual               Turtle Check Men Navy Blue Shirt
# 1  2012.0  Casual             Peter England Men Party Blue Jeans
# 2  2016.0  Casual                       Titan Women Silver Watch
# 3  2011.0  Casual  Manchester United Men Solid Black Track Pants
# 4  2012.0  Casual                          Puma Men Grey T-shirt
#
#                                          images_path  \
# 0  /content/drive/MyDrive/product_search_engine/d...
# ...

# %% [markdown]
# Save the input text processed file

# %%
OUT_PATH = f"{DATA_DIR}/text_processed.csv"
df.to_csv(OUT_PATH, index=False)
